# %% [markdown]
# # Reinforcement learning - Frozen-walk game

# %% [markdown]
# Frozen lake involves crossing a frozen lake from start to goal without falling into any holes by walking over the frozen lake. The player may not always move in the intended direction due to the slippery nature of the frozen lake.
#
# ![Frozen walk](https://gymnasium.farama.org/_images/frozen_lake.gif)
#
# More details can be found at https://gymnasium.farama.org/environments/toy_text/frozen_lake/.

# %% [markdown]
# ### Install libraries

# %%
# Install gymnasium game environment
# !pip install gymnasium[toy-text]
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting gymnasium[toy-text]
#   Downloading gymnasium-0.27.1-py3-none-any.whl (883 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 KB 18.8 MB/s eta 0:00:00
# Requirement already satisfied: importlib-metadata>=4.8.0 in /usr/local/lib/python3.8/dist-packages (from gymnasium[toy-text]) (6.0.0)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.8/dist-packages (from gymnasium[toy-text]) (1.21.6)
# Collecting jax-jumpy>=0.2.0
#   Downloading jax_jumpy-0.2.0-py3-none-any.whl (11 kB)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.8/dist-packages (from gymnasium[toy-text]) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.8/dist-packages (from gymnasium[toy-text]) (4.4.0)
# Collecting gymnasium-notices>=0.0.1
#   Downloading gymnasium_notices-0.0.1-py3-none-any.whl (2.8 kB)
# Collecting pygame==2.1.3.dev8
#   Downloading pygame-2.1.3.dev8-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.7/13.7 MB 33.4 MB/s eta 0:00:00
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata>=4.8.0->gymnasium[toy-text]) (3.12.0)
# Installing collected packages: gymnasium-notices, pygame, jax-jumpy, gymnasium
# Successfully installed gymnasium-0.27.1 gymnasium-notices-0.0.1 jax-jumpy-0.2.0 pygame-2.1.3.dev8

# %% [markdown]
# ### Import libraries and construct environment

# %%
# Load libraries
import gymnasium as gym
import numpy as np
import random
import matplotlib.pyplot as plt
import matplotlib
from keras.optimizers import Adam
from keras.layers import Dense
from keras.models import Sequential
from collections import deque
import imageio
import pandas as pd

# Define environment map
custom_map = [
    'SFF',
    'FHF',
    'FFG'
]

# Initialize the environment\
env = gym.make('FrozenLake-v1', desc=custom_map, is_slippery=False, render_mode='rgb_array')
state_size = env.observation_space.n    # Number of states
action_size = env.action_space.n    # Number of actions of this game: four, 0: left, 1:down, 2: right, 3: up.
env.reset()    # Reset environment, i.e., set agent position to state 0
plt.imshow(env.render())    # Visualize environment map

# %% [markdown]
# ### Define agent

# %%
# Define agent attibutes and methods
class Agent:
    def __init__(self, state_size, action_size):
        self.memory = deque(maxlen=2048)   # Deque is quick for append and pop operations from both the ends of the container.
        self.batch_size = 256    # Batch size of data samples for training policy (and target) network. In this example, the two networks are identical.
        self.learning_rate = 0.001    # Learning rate of 
        self.epsilon = 1    # Start (max) value of epsilon
        self.min_eps = 0.01    # End (min) value of epsilon
        self.eps_decay = 0.003     # Decay factor for decreasing epsilon over episodes
        self.gamma = 0.9    # Discount factor
        self.state_size = state_size    # Number of states
        self.action_size =  action_size    # Number of possible actions the agent can take: four, 0: left, 1:down, 2: right, 3: up.
        self.episode = 0     # Agent current episode
        # self.epsilon_lst = []    # Track epsilon values over episodes
        self.max_steps = 50    # Maximum number of steps the agent can carry out in an episode
        self.train_episodes = 501    # Number of training episodes
        self.model = self.build_model()    # Agent policy (and target model)

    # Build model architecture and compile it
    def build_model(self):
        model = Sequential()    # Initiate a simple sequential model
        model.add(Dense(10, input_dim=self.state_size, activation='relu'))    # Add a fully connected layer
        model.add(Dense(self.action_size, activation='linear'))    # Add a fully connected layer connecting to the network output
        model.compile(loss='mse', optimizer=Adam(learning_rate=self.learning_rate))    # Compile model with Mean Squared Error loss function
        return model

    # Add an eposide to agent's memory
    def add_memory(self, state, action, reward, new_state, terminated):
        self.memory.append((state, action, reward, new_state, terminated))    # Insert the value in its argument to the right end of the deque

    # Get action when agent is at a certain state
    def action(self, state):
        if np.random.rand() > self.epsilon:     # Epsilon starts at 1. rand > epsilon: exploit, rand <= epsilon: explore.
            return np.argmax(self.model.predict(state, verbose=0))     # Take greedy action. Verbose=0 mutes output prediction log.
        return env.action_space.sample()    # Take a random action in the action space

    # Train policy (and target) network. In this example, the two networks are identical.
    def replay(self):
        ### Process data batch
        minibatch = random.sample(self.memory, self.batch_size)    # Select a data batch for training
        minibatch_state = np.concatenate(np.array(minibatch, dtype=object)[:, 0], axis=0)    # Extract 'state' batch from the data batch
        minibatch_action = np.array(minibatch, dtype=object)[:, 1]    # Extract 'action' batch from the data batch
        minibatch_reward = np.array(minibatch, dtype=object)[:, 2]    # Extract 'reward' batch from the data batch
        minibatch_new_state = np.concatenate(np.array(minibatch, dtype=object)[:, 3], axis=0)    # Extract 'new_state' batch from the data batch
        minibatch_terminated = np.array(minibatch, dtype=object)[:, 4]    # Extract 'terminated' batch from the data batch

        ### Feed state to the network for training
        q_state = self.model.predict(minibatch_state, verbose=0)    # First pass: feed current state to the network to get current Q-values
        q_new_state = self.model.predict(minibatch_new_state, verbose=0)    # Second pass: feed new state to the network to get next Q-values

        q_action_optimal = np.add(minibatch_reward, self.gamma * np.amax(q_new_state, axis=1))    # Calculate the optimal Q-values of actions from the current state
        for i in range(0, self.batch_size):
            q_state[i][minibatch_action[i]] = q_action_optimal[i]    # Update optimal Q-values back to 'q_state' variable

        self.model.fit(minibatch_state, q_state, epochs=1, verbose=0)    # Train the network with the optimal Q-values, i.e., now in 'q_state' variable. x is minibatch_state and y is q_state. Loss is MSE.
    
    # Save model
    def save_model(self, name):
        self.model.save_weights(name)
    
    # Load model
    def load_model(self, name):
        self.model.load_weights(name)

# Initialize a reinforcement learning agent
agent = Agent(state_size, action_size)

# %% [markdown]
# ### Train the agent

# %%
reward_episodes = []    # Track rewards over episodes
step_episodes = []    # Track number of steps (in each episode until termination) over episodes
epsilon_episodes = []    # Track epsilon values over episodes

for episode in range(agent.train_episodes):
    agent.episode = episode    # Set agent's current episode 
    state = env.reset()    # Reset environment, i.e., agent position is set to state 0
    state_arr = np.zeros(agent.state_size)    # Initialze current state array, e.g., [0. 0. 0. 0. 0. 0. 0. 0. 0.]
    state_arr[state[0]] = 1    # Set the agent position in the current state array, i.e., [[1. 0. 0. 0. 0. 0. 0. 0. 0.]]
    state_arr = np.reshape(state_arr, [1, agent.state_size])    # Reshape array
    reward = 0    # Initialize reward to zero
    terminated = False    # Initialize terminated to False
    
    img_lst = [env.render()]    # Initialize list to store visualization frames
    for step in range(agent.max_steps):
        action = agent.action(state_arr)    # Take action at the current state. This ccan be exploitation or exploration, depending on agent.epsilon
        new_state, reward, terminated, info, _ = env.step(action)     # Terminated: whether a terminal state is reached after taking the action. Ref: https://www.gymlibrary.dev/api/core/#gym.Env.step
        new_state_arr = np.zeros(agent.state_size)    # Initialze new state array, e.g., [[0. 0. 0. 0. 0. 0. 0. 0. 0.]]
        new_state_arr[new_state] = 1    # Set the agent position in the new state array, after taking the action, e.g., [[0. 1. 0. 0. 0. 0. 0. 0. 0.]]
        new_state_arr = np.reshape(new_state_arr, [1, agent.state_size])    # Reshape array
        agent.add_memory(state_arr, action, reward, new_state_arr, terminated)    # Add current step to agent's memory
        state_arr = new_state_arr    # New state becomes state
        
        # Render map imgage for visualization every K episodes
        if agent.episode % 50 == 0:
            animation_file = "training_episode_" + str(agent.episode) + "_steps_" + str(step) + ".gif"
            img = env.render()    # Render current environment image
            img_lst.append(img)    # Append environment images to make animation
        
        if terminated:    # if agent reaches Goal
            break    # End episode

    print("Episode: " + str(agent.episode) + ", Steps: " + str(step) + ", epsilon: " + str(round(agent.epsilon,2)) + ", Reward: " + str(reward))
    reward_episodes.append(reward)    # Add reward to list for tracking purpose
    step_episodes.append(step)    # Add step to list for tracking purpose
    epsilon_episodes.append(agent.epsilon)    # Add epsilon to list for tracking purpose
    
    ### Update epsilon value which is the ratio of exploitation and exploration
    if agent.epsilon < agent.min_eps:
        agent.epsilon = agent.min_eps    # Set the minimum value of epsilon so that there is always a chance for exploration.
    else:
        agent.epsilon = np.exp(-agent.eps_decay*agent.episode)    # Decrease exploration / Increase exploitation overtime as the agent knows more about the environment

    ### If enough experiences collected in the memory, use them for training
    if len(agent.memory) > agent.batch_size:    
        agent.replay()
        
    ### Write animation of the training episode (n*K)th
    if len(img_lst)>1:    
        imageio.mimsave(animation_file, img_lst, format='GIF', duration=0.5)

print('Average success rate of training episodes: ', round(np.mean(reward_episodes),2))
agent.save_model('model_' + str(agent.episode))    # Save model
# Out:
# Episode: 0, Steps: 3, epsilon: 1, Reward: 0.0
# Episode: 1, Steps: 5, epsilon: 1.0, Reward: 0.0
# Episode: 2, Steps: 7, epsilon: 1.0, Reward: 0.0
# Episode: 3, Steps: 11, epsilon: 0.99, Reward: 1.0
# Episode: 4, Steps: 8, epsilon: 0.99, Reward: 1.0
# Episode: 5, Steps: 4, epsilon: 0.99, Reward: 0.0
# Episode: 6, Steps: 3, epsilon: 0.99, Reward: 0.0
# Episode: 7, Steps: 3, epsilon: 0.98, Reward: 0.0
# Episode: 8, Steps: 5, epsilon: 0.98, Reward: 0.0
# Episode: 9, Steps: 15, epsilon: 0.98, Reward: 0.0
# Episode: 10, Steps: 4, epsilon: 0.97, Reward: 0.0
# Episode: 11, Steps: 5, epsilon: 0.97, Reward: 0.0
# Episode: 12, Steps: 3, epsilon: 0.97, Reward: 0.0
# Episode: 13, Steps: 1, epsilon: 0.96, Reward: 0.0
# Episode: 14, Steps: 8, epsilon: 0.96, Reward: 0.0
# Episode: 15, Steps: 6, epsilon: 0.96, Reward: 0.0
# Episode: 16, Steps: 6, epsilon: 0.96, Reward: 0.0
# Episode: 17, Steps: 3, epsilon: 0.95, Reward: 0.0
# Episode: 18, Steps: 1, epsilon: 0.95, Reward: 0.0
# Episode: 19, Steps: 5, epsilon: 0.95, Reward: 0.0
# Episode: 20, Steps: 3, epsilon: 0.94, Reward: 0.0
# Episode: 21, Steps: 2, epsilon: 0.94, Reward: 0.0
# Episode: 22, Steps: 2, epsilon: 0.94, Reward: 0.0
# Episode: 23, Steps: 10, epsilon: 0.94, Reward: 0.0
# Episode: 24, Steps: 15, epsilon: 0.93, Reward: 0.0
# Episode: 25, Steps: 1, epsilon: 0.93, Reward: 0.0
# Episode: 26, Steps: 6, epsilon: 0.93, Reward: 0.0
# Episode: 27, Steps: 9, epsilon: 0.92, Reward: 1.0
# Episode: 28, Steps: 3, epsilon: 0.92, Reward: 0.0
# Episode: 29, Steps: 1, epsilon: 0.92, Reward: 0.0
# Episode: 30, Steps: 9, epsilon: 0.92, Reward: 1.0
# Episode: 31, Steps: 1, epsilon: 0.91, Reward: 0.0
# Episode: 32, Steps: 9, epsilon: 0.91, Reward: 0.0
# Episode: 33, Steps: 7, epsilon: 0.91, Reward: 0.0
# Episode: 34, Steps: 11, epsilon: 0.91, Reward: 1.0
# Episode: 35, Steps: 1, epsilon: 0.9, Reward: 0.0
# Episode: 36, Steps: 14, epsilon: 0.9, Reward: 1.0
# Episode: 37, Steps: 1, epsilon: 0.9, Reward: 0.0
# Episode: 38, Steps: 3, epsilon: 0.89, Reward: 0.0
# Episode: 39, Steps: 1, epsilon: 0.89, Reward: 0.0
# Episode: 40, Steps: 2, epsilon: 0.89, Reward: 0.0
# Episode: 41, Steps: 11, epsilon: 0.89, Reward: 1.0
# Episode: 42, Steps: 3, epsilon: 0.88, Reward: 0.0
# Episode: 43, Steps: 1, epsilon: 0.88, Reward: 0.0
# Episode: 44, Steps: 15, epsilon: 0.88, Reward: 0.0
# Episode: 45, Steps: 8, epsilon: 0.88, Reward: 0.0
# Episode: 46, Steps: 14, epsilon: 0.87, Reward: 0.0
# Episode: 47, Steps: 11, epsilon: 0.87, Reward: 0.0
# Episode: 48, Steps: 10, epsilon: 0.87, Reward: 1.0
# Episode: 49, Steps: 2, epsilon: 0.87, Reward: 0.0
# Episode: 50, Steps: 10, epsilon: 0.86, Reward: 0.0
# Episode: 51, Steps: 8, epsilon: 0.86, Reward: 0.0
# Episode: 52, Steps: 7, epsilon: 0.86, Reward: 0.0
# Episode: 53, Steps: 2, epsilon: 0.86, Reward: 0.0
# Episode: 54, Steps: 16, epsilon: 0.85, Reward: 0.0
# Episode: 55, Steps: 23, epsilon: 0.85, Reward: 0.0
# Episode: 56, Steps: 7, epsilon: 0.85, Reward: 0.0
# Episode: 57, Steps: 8, epsilon: 0.85, Reward: 0.0
# Episode: 58, Steps: 18, epsilon: 0.84, Reward: 0.0
# Episode: 59, Steps: 1, epsilon: 0.84, Reward: 0.0
# Episode: 60, Steps: 4, epsilon: 0.84, Reward: 0.0
# Episode: 61, Steps: 36, epsilon: 0.84, Reward: 0.0
# Episode: 62, Steps: 3, epsilon: 0.83, Reward: 0.0
# Episode: 63, Steps: 9, epsilon: 0.83, Reward: 0.0
# Episode: 64, Steps: 2, epsilon: 0.83, Reward: 0.0
# Episode: 65, Steps: 2, epsilon: 0.83, Reward: 0.0
# Episode: 66, Steps: 11, epsilon: 0.82, Reward: 0.0
# Episode: 67, Steps: 1, epsilon: 0.82, Reward: 0.0
# Episode: 68, Steps: 17, epsilon: 0.82, Reward: 0.0
# Episode: 69, Steps: 6, epsilon: 0.82, Reward: 0.0
# Episode: 70, Steps: 18, epsilon: 0.81, Reward: 0.0
# Episode: 71, Steps: 2, epsilon: 0.81, Reward: 0.0
# Episode: 72, Steps: 1, epsilon: 0.81, Reward: 0.0
# Episode: 73, Steps: 11, epsilon: 0.81, Reward: 1.0
# Episode: 74, Steps: 5, epsilon: 0.8, Reward: 0.0
# Episode: 75, Steps: 17, epsilon: 0.8, Reward: 0.0
# Episode: 76, Steps: 5, epsilon: 0.8, Reward: 0.0
# Episode: 77, Steps: 22, epsilon: 0.8, Reward: 1.0
# Episode: 78, Steps: 15, epsilon: 0.79, Reward: 0.0
# Episode: 79, Steps: 4, epsilon: 0.79, Reward: 0.0
# Episode: 80, Steps: 2, epsilon: 0.79, Reward: 0.0
# Episode: 81, Steps: 1, epsilon: 0.79, Reward: 0.0
# Episode: 82, Steps: 5, epsilon: 0.78, Reward: 0.0
# Episode: 83, Steps: 1, epsilon: 0.78, Reward: 0.0
# Episode: 84, Steps: 15, epsilon: 0.78, Reward: 1.0
# Episode: 85, Steps: 5, epsilon: 0.78, Reward: 0.0
# Episode: 86, Steps: 5, epsilon: 0.77, Reward: 0.0
# Episode: 87, Steps: 9, epsilon: 0.77, Reward: 1.0
# Episode: 88, Steps: 4, epsilon: 0.77, Reward: 0.0
# Episode: 89, Steps: 4, epsilon: 0.77, Reward: 0.0
# Episode: 90, Steps: 10, epsilon: 0.77, Reward: 0.0
# Episode: 91, Steps: 6, epsilon: 0.76, Reward: 0.0
# Episode: 92, Steps: 6, epsilon: 0.76, Reward: 0.0
# Episode: 93, Steps: 25, epsilon: 0.76, Reward: 0.0
# Episode: 94, Steps: 4, epsilon: 0.76, Reward: 1.0
# Episode: 95, Steps: 3, epsilon: 0.75, Reward: 0.0
# Episode: 96, Steps: 16, epsilon: 0.75, Reward: 1.0
# Episode: 97, Steps: 25, epsilon: 0.75, Reward: 0.0
# Episode: 98, Steps: 9, epsilon: 0.75, Reward: 1.0
# Episode: 99, Steps: 5, epsilon: 0.75, Reward: 1.0
# Episode: 100, Steps: 1, epsilon: 0.74, Reward: 0.0
# Episode: 101, Steps: 3, epsilon: 0.74, Reward: 0.0
# Episode: 102, Steps: 4, epsilon: 0.74, Reward: 1.0
# Episode: 103, Steps: 19, epsilon: 0.74, Reward: 1.0
# Episode: 104, Steps: 4, epsilon: 0.73, Reward: 0.0
# Episode: 105, Steps: 1, epsilon: 0.73, Reward: 0.0
# Episode: 106, Steps: 2, epsilon: 0.73, Reward: 0.0
# Episode: 107, Steps: 3, epsilon: 0.73, Reward: 0.0
# Episode: 108, Steps: 3, epsilon: 0.73, Reward: 0.0
# Episode: 109, Steps: 3, epsilon: 0.72, Reward: 0.0
# Episode: 110, Steps: 4, epsilon: 0.72, Reward: 1.0
# Episode: 111, Steps: 6, epsilon: 0.72, Reward: 0.0
# Episode: 112, Steps: 5, epsilon: 0.72, Reward: 1.0
# Episode: 113, Steps: 5, epsilon: 0.71, Reward: 1.0
# Episode: 114, Steps: 4, epsilon: 0.71, Reward: 1.0
# Episode: 115, Steps: 5, epsilon: 0.71, Reward: 1.0
# Episode: 116, Steps: 3, epsilon: 0.71, Reward: 1.0
# Episode: 117, Steps: 1, epsilon: 0.71, Reward: 0.0
# Episode: 118, Steps: 9, epsilon: 0.7, Reward: 1.0
# Episode: 119, Steps: 7, epsilon: 0.7, Reward: 1.0
# Episode: 120, Steps: 3, epsilon: 0.7, Reward: 1.0
# Episode: 121, Steps: 11, epsilon: 0.7, Reward: 1.0
# Episode: 122, Steps: 7, epsilon: 0.7, Reward: 0.0
# Episode: 123, Steps: 3, epsilon: 0.69, Reward: 1.0
# Episode: 124, Steps: 7, epsilon: 0.69, Reward: 0.0
# Episode: 125, Steps: 5, epsilon: 0.69, Reward: 1.0
# Episode: 126, Steps: 1, epsilon: 0.69, Reward: 0.0
# Episode: 127, Steps: 4, epsilon: 0.69, Reward: 1.0
# Episode: 128, Steps: 12, epsilon: 0.68, Reward: 0.0
# Episode: 129, Steps: 8, epsilon: 0.68, Reward: 0.0
# Episode: 130, Steps: 8, epsilon: 0.68, Reward: 0.0
# Episode: 131, Steps: 7, epsilon: 0.68, Reward: 1.0
# Episode: 132, Steps: 4, epsilon: 0.68, Reward: 0.0
# Episode: 133, Steps: 5, epsilon: 0.67, Reward: 0.0
# Episode: 134, Steps: 1, epsilon: 0.67, Reward: 0.0
# Episode: 135, Steps: 6, epsilon: 0.67, Reward: 1.0
# Episode: 136, Steps: 9, epsilon: 0.67, Reward: 1.0
# Episode: 137, Steps: 12, epsilon: 0.66, Reward: 1.0
# Episode: 138, Steps: 3, epsilon: 0.66, Reward: 1.0
# Episode: 139, Steps: 10, epsilon: 0.66, Reward: 0.0
# Episode: 140, Steps: 7, epsilon: 0.66, Reward: 1.0
# Episode: 141, Steps: 7, epsilon: 0.66, Reward: 0.0
# Episode: 142, Steps: 19, epsilon: 0.66, Reward: 0.0
# Episode: 143, Steps: 3, epsilon: 0.65, Reward: 0.0
# Episode: 144, Steps: 1, epsilon: 0.65, Reward: 0.0
# Episode: 145, Steps: 4, epsilon: 0.65, Reward: 1.0
# Episode: 146, Steps: 3, epsilon: 0.65, Reward: 1.0
# Episode: 147, Steps: 4, epsilon: 0.65, Reward: 0.0
# Episode: 148, Steps: 5, epsilon: 0.64, Reward: 1.0
# Episode: 149, Steps: 1, epsilon: 0.64, Reward: 0.0
# Episode: 150, Steps: 1, epsilon: 0.64, Reward: 0.0
# Episode: 151, Steps: 5, epsilon: 0.64, Reward: 1.0
# Episode: 152, Steps: 5, epsilon: 0.64, Reward: 1.0
# Episode: 153, Steps: 4, epsilon: 0.63, Reward: 1.0
# Episode: 154, Steps: 4, epsilon: 0.63, Reward: 1.0
# Episode: 155, Steps: 4, epsilon: 0.63, Reward: 1.0
# Episode: 156, Steps: 3, epsilon: 0.63, Reward: 1.0
# Episode: 157, Steps: 7, epsilon: 0.63, Reward: 0.0
# Episode: 158, Steps: 5, epsilon: 0.62, Reward: 1.0
# Episode: 159, Steps: 14, epsilon: 0.62, Reward: 0.0
# Episode: 160, Steps: 5, epsilon: 0.62, Reward: 1.0
# Episode: 161, Steps: 15, epsilon: 0.62, Reward: 1.0
# Episode: 162, Steps: 15, epsilon: 0.62, Reward: 0.0
# Episode: 163, Steps: 1, epsilon: 0.62, Reward: 0.0
# Episode: 164, Steps: 3, epsilon: 0.61, Reward: 0.0
# Episode: 165, Steps: 8, epsilon: 0.61, Reward: 1.0
# Episode: 166, Steps: 1, epsilon: 0.61, Reward: 0.0
# Episode: 167, Steps: 13, epsilon: 0.61, Reward: 0.0
# Episode: 168, Steps: 10, epsilon: 0.61, Reward: 1.0
# Episode: 169, Steps: 3, epsilon: 0.6, Reward: 1.0
# Episode: 170, Steps: 1, epsilon: 0.6, Reward: 0.0
# Episode: 171, Steps: 3, epsilon: 0.6, Reward: 1.0
# Episode: 172, Steps: 7, epsilon: 0.6, Reward: 1.0
# Episode: 173, Steps: 1, epsilon: 0.6, Reward: 0.0
# Episode: 174, Steps: 5, epsilon: 0.6, Reward: 0.0
# Episode: 175, Steps: 5, epsilon: 0.59, Reward: 1.0
# Episode: 176, Steps: 1, epsilon: 0.59, Reward: 0.0
# Episode: 177, Steps: 8, epsilon: 0.59, Reward: 0.0
# Episode: 178, Steps: 10, epsilon: 0.59, Reward: 0.0
# Episode: 179, Steps: 5, epsilon: 0.59, Reward: 1.0
# Episode: 180, Steps: 4, epsilon: 0.58, Reward: 0.0
# Episode: 181, Steps: 7, epsilon: 0.58, Reward: 1.0
# Episode: 182, Steps: 9, epsilon: 0.58, Reward: 1.0
# Episode: 183, Steps: 3, epsilon: 0.58, Reward: 0.0
# Episode: 184, Steps: 6, epsilon: 0.58, Reward: 0.0
# Episode: 185, Steps: 12, epsilon: 0.58, Reward: 1.0
# Episode: 186, Steps: 5, epsilon: 0.57, Reward: 1.0
# Episode: 187, Steps: 7, epsilon: 0.57, Reward: 1.0
# Episode: 188, Steps: 3, epsilon: 0.57, Reward: 1.0
# Episode: 189, Steps: 7, epsilon: 0.57, Reward: 0.0
# Episode: 190, Steps: 9, epsilon: 0.57, Reward: 1.0
# Episode: 191, Steps: 4, epsilon: 0.57, Reward: 1.0
# Episode: 192, Steps: 4, epsilon: 0.56, Reward: 1.0
# Episode: 193, Steps: 5, epsilon: 0.56, Reward: 1.0
# Episode: 194, Steps: 8, epsilon: 0.56, Reward: 1.0
# Episode: 195, Steps: 5, epsilon: 0.56, Reward: 1.0
# Episode: 196, Steps: 3, epsilon: 0.56, Reward: 1.0
# Episode: 197, Steps: 5, epsilon: 0.56, Reward: 0.0
# Episode: 198, Steps: 3, epsilon: 0.55, Reward: 1.0
# Episode: 199, Steps: 3, epsilon: 0.55, Reward: 0.0
# Episode: 200, Steps: 12, epsilon: 0.55, Reward: 0.0
# Episode: 201, Steps: 3, epsilon: 0.55, Reward: 0.0
# Episode: 202, Steps: 4, epsilon: 0.55, Reward: 1.0
# Episode: 203, Steps: 3, epsilon: 0.55, Reward: 0.0
# Episode: 204, Steps: 4, epsilon: 0.54, Reward: 1.0
# Episode: 205, Steps: 4, epsilon: 0.54, Reward: 1.0
# Episode: 206, Steps: 3, epsilon: 0.54, Reward: 0.0
# Episode: 207, Steps: 8, epsilon: 0.54, Reward: 1.0
# Episode: 208, Steps: 3, epsilon: 0.54, Reward: 1.0
# Episode: 209, Steps: 1, epsilon: 0.54, Reward: 0.0
# Episode: 210, Steps: 5, epsilon: 0.53, Reward: 1.0
# Episode: 211, Steps: 14, epsilon: 0.53, Reward: 1.0
# Episode: 212, Steps: 4, epsilon: 0.53, Reward: 1.0
# Episode: 213, Steps: 4, epsilon: 0.53, Reward: 1.0
# Episode: 214, Steps: 7, epsilon: 0.53, Reward: 1.0
# Episode: 215, Steps: 1, epsilon: 0.53, Reward: 0.0
# Episode: 216, Steps: 11, epsilon: 0.52, Reward: 1.0
# Episode: 217, Steps: 4, epsilon: 0.52, Reward: 1.0
# Episode: 218, Steps: 8, epsilon: 0.52, Reward: 1.0
# Episode: 219, Steps: 1, epsilon: 0.52, Reward: 0.0
# Episode: 220, Steps: 5, epsilon: 0.52, Reward: 0.0
# Episode: 221, Steps: 3, epsilon: 0.52, Reward: 1.0
# Episode: 222, Steps: 3, epsilon: 0.52, Reward: 0.0
# Episode: 223, Steps: 9, epsilon: 0.51, Reward: 1.0
# Episode: 224, Steps: 3, epsilon: 0.51, Reward: 1.0
# Episode: 225, Steps: 7, epsilon: 0.51, Reward: 0.0
# Episode: 226, Steps: 3, epsilon: 0.51, Reward: 1.0
# Episode: 227, Steps: 2, epsilon: 0.51, Reward: 0.0
# Episode: 228, Steps: 7, epsilon: 0.51, Reward: 1.0
# Episode: 229, Steps: 5, epsilon: 0.5, Reward: 1.0
# Episode: 230, Steps: 7, epsilon: 0.5, Reward: 1.0
# Episode: 231, Steps: 4, epsilon: 0.5, Reward: 1.0
# Episode: 232, Steps: 3, epsilon: 0.5, Reward: 0.0
# Episode: 233, Steps: 3, epsilon: 0.5, Reward: 1.0
# Episode: 234, Steps: 4, epsilon: 0.5, Reward: 1.0
# Episode: 235, Steps: 4, epsilon: 0.5, Reward: 1.0
# Episode: 236, Steps: 5, epsilon: 0.49, Reward: 1.0
# Episode: 237, Steps: 9, epsilon: 0.49, Reward: 1.0
# Episode: 238, Steps: 5, epsilon: 0.49, Reward: 1.0
# Episode: 239, Steps: 3, epsilon: 0.49, Reward: 1.0
# Episode: 240, Steps: 6, epsilon: 0.49, Reward: 1.0
# Episode: 241, Steps: 6, epsilon: 0.49, Reward: 1.0
# Episode: 242, Steps: 3, epsilon: 0.49, Reward: 0.0
# Episode: 243, Steps: 4, epsilon: 0.48, Reward: 1.0
# Episode: 244, Steps: 5, epsilon: 0.48, Reward: 1.0
# Episode: 245, Steps: 3, epsilon: 0.48, Reward: 1.0
# Episode: 246, Steps: 5, epsilon: 0.48, Reward: 1.0
# Episode: 247, Steps: 7, epsilon: 0.48, Reward: 1.0
# Episode: 248, Steps: 9, epsilon: 0.48, Reward: 0.0
# Episode: 249, Steps: 10, epsilon: 0.48, Reward: 1.0
# Episode: 250, Steps: 6, epsilon: 0.47, Reward: 1.0
# Episode: 251, Steps: 3, epsilon: 0.47, Reward: 1.0
# Episode: 252, Steps: 3, epsilon: 0.47, Reward: 0.0
# Episode: 253, Steps: 9, epsilon: 0.47, Reward: 1.0
# Episode: 254, Steps: 4, epsilon: 0.47, Reward: 1.0
# Episode: 255, Steps: 5, epsilon: 0.47, Reward: 1.0
# Episode: 256, Steps: 5, epsilon: 0.47, Reward: 1.0
# Episode: 257, Steps: 3, epsilon: 0.46, Reward: 1.0
# Episode: 258, Steps: 6, epsilon: 0.46, Reward: 1.0
# Episode: 259, Steps: 6, epsilon: 0.46, Reward: 0.0
# Episode: 260, Steps: 3, epsilon: 0.46, Reward: 1.0
# Episode: 261, Steps: 3, epsilon: 0.46, Reward: 1.0
# Episode: 262, Steps: 5, epsilon: 0.46, Reward: 0.0
# Episode: 263, Steps: 3, epsilon: 0.46, Reward: 1.0
# Episode: 264, Steps: 3, epsilon: 0.45, Reward: 1.0
# Episode: 265, Steps: 3, epsilon: 0.45, Reward: 1.0
# Episode: 266, Steps: 1, epsilon: 0.45, Reward: 0.0
# Episode: 267, Steps: 6, epsilon: 0.45, Reward: 1.0
# Episode: 268, Steps: 6, epsilon: 0.45, Reward: 0.0
# Episode: 269, Steps: 3, epsilon: 0.45, Reward: 1.0
# Episode: 270, Steps: 1, epsilon: 0.45, Reward: 0.0
# Episode: 271, Steps: 5, epsilon: 0.44, Reward: 1.0
# Episode: 272, Steps: 5, epsilon: 0.44, Reward: 1.0
# Episode: 273, Steps: 6, epsilon: 0.44, Reward: 1.0
# Episode: 274, Steps: 1, epsilon: 0.44, Reward: 0.0
# Episode: 275, Steps: 9, epsilon: 0.44, Reward: 1.0
# Episode: 276, Steps: 6, epsilon: 0.44, Reward: 1.0
# Episode: 277, Steps: 5, epsilon: 0.44, Reward: 0.0
# Episode: 278, Steps: 3, epsilon: 0.44, Reward: 0.0
# Episode: 279, Steps: 3, epsilon: 0.43, Reward: 1.0
# Episode: 280, Steps: 3, epsilon: 0.43, Reward: 1.0
# Episode: 281, Steps: 3, epsilon: 0.43, Reward: 0.0
# Episode: 282, Steps: 5, epsilon: 0.43, Reward: 1.0
# Episode: 283, Steps: 1, epsilon: 0.43, Reward: 0.0
# Episode: 284, Steps: 6, epsilon: 0.43, Reward: 1.0
# Episode: 285, Steps: 3, epsilon: 0.43, Reward: 1.0
# Episode: 286, Steps: 3, epsilon: 0.43, Reward: 1.0
# Episode: 287, Steps: 5, epsilon: 0.42, Reward: 1.0
# Episode: 288, Steps: 4, epsilon: 0.42, Reward: 1.0
# Episode: 289, Steps: 3, epsilon: 0.42, Reward: 1.0
# Episode: 290, Steps: 10, epsilon: 0.42, Reward: 0.0
# Episode: 291, Steps: 6, epsilon: 0.42, Reward: 0.0
# Episode: 292, Steps: 3, epsilon: 0.42, Reward: 1.0
# Episode: 293, Steps: 3, epsilon: 0.42, Reward: 1.0
# Episode: 294, Steps: 3, epsilon: 0.42, Reward: 1.0
# Episode: 295, Steps: 5, epsilon: 0.41, Reward: 1.0
# Episode: 296, Steps: 5, epsilon: 0.41, Reward: 1.0
# Episode: 297, Steps: 4, epsilon: 0.41, Reward: 1.0
# Episode: 298, Steps: 3, epsilon: 0.41, Reward: 0.0
# Episode: 299, Steps: 6, epsilon: 0.41, Reward: 1.0
# Episode: 300, Steps: 4, epsilon: 0.41, Reward: 1.0
# Episode: 301, Steps: 5, epsilon: 0.41, Reward: 1.0
# Episode: 302, Steps: 6, epsilon: 0.41, Reward: 1.0
# Episode: 303, Steps: 5, epsilon: 0.4, Reward: 1.0
# Episode: 304, Steps: 3, epsilon: 0.4, Reward: 1.0
# Episode: 305, Steps: 3, epsilon: 0.4, Reward: 1.0
# Episode: 306, Steps: 10, epsilon: 0.4, Reward: 1.0
# Episode: 307, Steps: 5, epsilon: 0.4, Reward: 1.0
# Episode: 308, Steps: 3, epsilon: 0.4, Reward: 0.0
# Episode: 309, Steps: 4, epsilon: 0.4, Reward: 1.0
# Episode: 310, Steps: 3, epsilon: 0.4, Reward: 1.0
# Episode: 311, Steps: 5, epsilon: 0.39, Reward: 1.0
# Episode: 312, Steps: 3, epsilon: 0.39, Reward: 1.0
# Episode: 313, Steps: 7, epsilon: 0.39, Reward: 1.0
# Episode: 314, Steps: 3, epsilon: 0.39, Reward: 1.0
# Episode: 315, Steps: 6, epsilon: 0.39, Reward: 0.0
# Episode: 316, Steps: 6, epsilon: 0.39, Reward: 1.0
# Episode: 317, Steps: 5, epsilon: 0.39, Reward: 1.0
# Episode: 318, Steps: 8, epsilon: 0.39, Reward: 1.0
# Episode: 319, Steps: 3, epsilon: 0.39, Reward: 1.0
# Episode: 320, Steps: 3, epsilon: 0.38, Reward: 1.0
# Episode: 321, Steps: 1, epsilon: 0.38, Reward: 0.0
# Episode: 322, Steps: 3, epsilon: 0.38, Reward: 1.0
# Episode: 323, Steps: 4, epsilon: 0.38, Reward: 1.0
# Episode: 324, Steps: 4, epsilon: 0.38, Reward: 1.0
# Episode: 325, Steps: 3, epsilon: 0.38, Reward: 1.0
# Episode: 326, Steps: 7, epsilon: 0.38, Reward: 1.0
# Episode: 327, Steps: 3, epsilon: 0.38, Reward: 1.0
# Episode: 328, Steps: 6, epsilon: 0.37, Reward: 1.0
# Episode: 329, Steps: 3, epsilon: 0.37, Reward: 1.0
# Episode: 330, Steps: 9, epsilon: 0.37, Reward: 1.0
# Episode: 331, Steps: 4, epsilon: 0.37, Reward: 1.0
# Episode: 332, Steps: 5, epsilon: 0.37, Reward: 1.0
# Episode: 333, Steps: 6, epsilon: 0.37, Reward: 1.0
# Episode: 334, Steps: 4, epsilon: 0.37, Reward: 0.0
# Episode: 335, Steps: 5, epsilon: 0.37, Reward: 1.0
# Episode: 336, Steps: 3, epsilon: 0.37, Reward: 1.0
# Episode: 337, Steps: 3, epsilon: 0.36, Reward: 1.0
# Episode: 338, Steps: 6, epsilon: 0.36, Reward: 1.0
# Episode: 339, Steps: 3, epsilon: 0.36, Reward: 1.0
# Episode: 340, Steps: 3, epsilon: 0.36, Reward: 1.0
# Episode: 341, Steps: 4, epsilon: 0.36, Reward: 1.0
# Episode: 342, Steps: 3, epsilon: 0.36, Reward: 1.0
# Episode: 343, Steps: 1, epsilon: 0.36, Reward: 0.0
# Episode: 344, Steps: 3, epsilon: 0.36, Reward: 1.0
# Episode: 345, Steps: 3, epsilon: 0.36, Reward: 1.0
# Episode: 346, Steps: 3, epsilon: 0.36, Reward: 1.0
# Episode: 347, Steps: 7, epsilon: 0.35, Reward: 0.0
# Episode: 348, Steps: 1, epsilon: 0.35, Reward: 0.0
# Episode: 349, Steps: 2, epsilon: 0.35, Reward: 0.0
# Episode: 350, Steps: 3, epsilon: 0.35, Reward: 1.0
# Episode: 351, Steps: 5, epsilon: 0.35, Reward: 1.0
# Episode: 352, Steps: 4, epsilon: 0.35, Reward: 0.0
# Episode: 353, Steps: 3, epsilon: 0.35, Reward: 1.0
# Episode: 354, Steps: 1, epsilon: 0.35, Reward: 0.0
# Episode: 355, Steps: 1, epsilon: 0.35, Reward: 0.0
# Episode: 356, Steps: 3, epsilon: 0.34, Reward: 1.0
# Episode: 357, Steps: 1, epsilon: 0.34, Reward: 0.0
# Episode: 358, Steps: 3, epsilon: 0.34, Reward: 1.0
# Episode: 359, Steps: 3, epsilon: 0.34, Reward: 1.0
# Episode: 360, Steps: 3, epsilon: 0.34, Reward: 1.0
# Episode: 361, Steps: 4, epsilon: 0.34, Reward: 1.0
# Episode: 362, Steps: 5, epsilon: 0.34, Reward: 1.0
# Episode: 363, Steps: 1, epsilon: 0.34, Reward: 0.0
# Episode: 364, Steps: 1, epsilon: 0.34, Reward: 0.0
# Episode: 365, Steps: 3, epsilon: 0.34, Reward: 1.0
# Episode: 366, Steps: 3, epsilon: 0.33, Reward: 1.0
# Episode: 367, Steps: 10, epsilon: 0.33, Reward: 1.0
# Episode: 368, Steps: 1, epsilon: 0.33, Reward: 0.0
# Episode: 369, Steps: 3, epsilon: 0.33, Reward: 1.0
# Episode: 370, Steps: 6, epsilon: 0.33, Reward: 1.0
# Episode: 371, Steps: 4, epsilon: 0.33, Reward: 1.0
# Episode: 372, Steps: 6, epsilon: 0.33, Reward: 1.0
# Episode: 373, Steps: 3, epsilon: 0.33, Reward: 1.0
# Episode: 374, Steps: 2, epsilon: 0.33, Reward: 0.0
# Episode: 375, Steps: 6, epsilon: 0.33, Reward: 1.0
# Episode: 376, Steps: 3, epsilon: 0.32, Reward: 1.0
# Episode: 377, Steps: 1, epsilon: 0.32, Reward: 0.0
# Episode: 378, Steps: 3, epsilon: 0.32, Reward: 1.0
# Episode: 379, Steps: 3, epsilon: 0.32, Reward: 0.0
# Episode: 380, Steps: 3, epsilon: 0.32, Reward: 1.0
# Episode: 381, Steps: 4, epsilon: 0.32, Reward: 1.0
# Episode: 382, Steps: 3, epsilon: 0.32, Reward: 0.0
# Episode: 383, Steps: 4, epsilon: 0.32, Reward: 1.0
# Episode: 384, Steps: 3, epsilon: 0.32, Reward: 1.0
# Episode: 385, Steps: 3, epsilon: 0.32, Reward: 0.0
# Episode: 386, Steps: 3, epsilon: 0.32, Reward: 1.0
# Episode: 387, Steps: 5, epsilon: 0.31, Reward: 1.0
# Episode: 388, Steps: 1, epsilon: 0.31, Reward: 0.0
# Episode: 389, Steps: 7, epsilon: 0.31, Reward: 1.0
# Episode: 390, Steps: 3, epsilon: 0.31, Reward: 1.0
# Episode: 391, Steps: 5, epsilon: 0.31, Reward: 1.0
# Episode: 392, Steps: 3, epsilon: 0.31, Reward: 1.0
# Episode: 393, Steps: 6, epsilon: 0.31, Reward: 1.0
# Episode: 394, Steps: 7, epsilon: 0.31, Reward: 1.0
# Episode: 395, Steps: 5, epsilon: 0.31, Reward: 1.0
# Episode: 396, Steps: 3, epsilon: 0.31, Reward: 1.0
# Episode: 397, Steps: 3, epsilon: 0.3, Reward: 1.0
# Episode: 398, Steps: 3, epsilon: 0.3, Reward: 1.0
# Episode: 399, Steps: 3, epsilon: 0.3, Reward: 0.0
# Episode: 400, Steps: 3, epsilon: 0.3, Reward: 1.0
# Episode: 401, Steps: 3, epsilon: 0.3, Reward: 1.0
# Episode: 402, Steps: 6, epsilon: 0.3, Reward: 1.0
# Episode: 403, Steps: 1, epsilon: 0.3, Reward: 0.0
# Episode: 404, Steps: 4, epsilon: 0.3, Reward: 1.0
# Episode: 405, Steps: 3, epsilon: 0.3, Reward: 0.0
# Episode: 406, Steps: 3, epsilon: 0.3, Reward: 1.0
# Episode: 407, Steps: 3, epsilon: 0.3, Reward: 1.0
# Episode: 408, Steps: 4, epsilon: 0.29, Reward: 1.0
# Episode: 409, Steps: 4, epsilon: 0.29, Reward: 1.0
# Episode: 410, Steps: 3, epsilon: 0.29, Reward: 0.0
# Episode: 411, Steps: 8, epsilon: 0.29, Reward: 1.0
# Episode: 412, Steps: 4, epsilon: 0.29, Reward: 1.0
# Episode: 413, Steps: 4, epsilon: 0.29, Reward: 0.0
# Episode: 414, Steps: 4, epsilon: 0.29, Reward: 1.0
# Episode: 415, Steps: 6, epsilon: 0.29, Reward: 1.0
# Episode: 416, Steps: 4, epsilon: 0.29, Reward: 1.0
# Episode: 417, Steps: 7, epsilon: 0.29, Reward: 1.0
# Episode: 418, Steps: 5, epsilon: 0.29, Reward: 1.0
# Episode: 419, Steps: 5, epsilon: 0.29, Reward: 1.0
# Episode: 420, Steps: 3, epsilon: 0.28, Reward: 1.0
# Episode: 421, Steps: 6, epsilon: 0.28, Reward: 1.0
# Episode: 422, Steps: 3, epsilon: 0.28, Reward: 1.0
# Episode: 423, Steps: 3, epsilon: 0.28, Reward: 1.0
# Episode: 424, Steps: 3, epsilon: 0.28, Reward: 1.0
# Episode: 425, Steps: 3, epsilon: 0.28, Reward: 1.0
# Episode: 426, Steps: 4, epsilon: 0.28, Reward: 1.0
# Episode: 427, Steps: 4, epsilon: 0.28, Reward: 1.0
# Episode: 428, Steps: 3, epsilon: 0.28, Reward: 1.0
# Episode: 429, Steps: 3, epsilon: 0.28, Reward: 1.0
# Episode: 430, Steps: 4, epsilon: 0.28, Reward: 1.0
# Episode: 431, Steps: 3, epsilon: 0.28, Reward: 1.0
# Episode: 432, Steps: 1, epsilon: 0.27, Reward: 0.0
# Episode: 433, Steps: 4, epsilon: 0.27, Reward: 1.0
# Episode: 434, Steps: 3, epsilon: 0.27, Reward: 1.0
# Episode: 435, Steps: 7, epsilon: 0.27, Reward: 1.0
# Episode: 436, Steps: 5, epsilon: 0.27, Reward: 0.0
# Episode: 437, Steps: 3, epsilon: 0.27, Reward: 1.0
# Episode: 438, Steps: 6, epsilon: 0.27, Reward: 1.0
# Episode: 439, Steps: 1, epsilon: 0.27, Reward: 0.0
# Episode: 440, Steps: 3, epsilon: 0.27, Reward: 1.0
# Episode: 441, Steps: 4, epsilon: 0.27, Reward: 1.0
# Episode: 442, Steps: 4, epsilon: 0.27, Reward: 1.0
# Episode: 443, Steps: 5, epsilon: 0.27, Reward: 1.0
# Episode: 444, Steps: 7, epsilon: 0.26, Reward: 1.0
# Episode: 445, Steps: 5, epsilon: 0.26, Reward: 1.0
# Episode: 446, Steps: 3, epsilon: 0.26, Reward: 0.0
# Episode: 447, Steps: 4, epsilon: 0.26, Reward: 1.0
# Episode: 448, Steps: 4, epsilon: 0.26, Reward: 0.0
# Episode: 449, Steps: 3, epsilon: 0.26, Reward: 1.0
# Episode: 450, Steps: 3, epsilon: 0.26, Reward: 1.0
# Episode: 451, Steps: 4, epsilon: 0.26, Reward: 1.0
# Episode: 452, Steps: 3, epsilon: 0.26, Reward: 1.0
# Episode: 453, Steps: 5, epsilon: 0.26, Reward: 1.0
# Episode: 454, Steps: 4, epsilon: 0.26, Reward: 1.0
# Episode: 455, Steps: 3, epsilon: 0.26, Reward: 1.0
# Episode: 456, Steps: 3, epsilon: 0.26, Reward: 1.0
# Episode: 457, Steps: 3, epsilon: 0.25, Reward: 1.0
# Episode: 458, Steps: 4, epsilon: 0.25, Reward: 1.0
# Episode: 459, Steps: 6, epsilon: 0.25, Reward: 1.0
# Episode: 460, Steps: 1, epsilon: 0.25, Reward: 0.0
# Episode: 461, Steps: 3, epsilon: 0.25, Reward: 1.0
# Episode: 462, Steps: 3, epsilon: 0.25, Reward: 1.0
# Episode: 463, Steps: 3, epsilon: 0.25, Reward: 1.0
# Episode: 464, Steps: 3, epsilon: 0.25, Reward: 1.0
# Episode: 465, Steps: 3, epsilon: 0.25, Reward: 1.0
# Episode: 466, Steps: 3, epsilon: 0.25, Reward: 1.0
# Episode: 467, Steps: 4, epsilon: 0.25, Reward: 1.0
# Episode: 468, Steps: 7, epsilon: 0.25, Reward: 0.0
# Episode: 469, Steps: 3, epsilon: 0.25, Reward: 1.0
# Episode: 470, Steps: 10, epsilon: 0.24, Reward: 1.0
# Episode: 471, Steps: 4, epsilon: 0.24, Reward: 1.0
# Episode: 472, Steps: 3, epsilon: 0.24, Reward: 1.0
# Episode: 473, Steps: 3, epsilon: 0.24, Reward: 1.0
# Episode: 474, Steps: 1, epsilon: 0.24, Reward: 0.0
# Episode: 475, Steps: 3, epsilon: 0.24, Reward: 1.0
# Episode: 476, Steps: 3, epsilon: 0.24, Reward: 1.0
# Episode: 477, Steps: 3, epsilon: 0.24, Reward: 1.0
# Episode: 478, Steps: 3, epsilon: 0.24, Reward: 1.0
# Episode: 479, Steps: 3, epsilon: 0.24, Reward: 1.0
# Episode: 480, Steps: 3, epsilon: 0.24, Reward: 1.0
# Episode: 481, Steps: 5, epsilon: 0.24, Reward: 1.0
# Episode: 482, Steps: 3, epsilon: 0.24, Reward: 1.0
# Episode: 483, Steps: 4, epsilon: 0.24, Reward: 0.0
# Episode: 484, Steps: 2, epsilon: 0.23, Reward: 0.0
# Episode: 485, Steps: 4, epsilon: 0.23, Reward: 1.0
# Episode: 486, Steps: 7, epsilon: 0.23, Reward: 1.0
# Episode: 487, Steps: 3, epsilon: 0.23, Reward: 1.0
# Episode: 488, Steps: 6, epsilon: 0.23, Reward: 1.0
# Episode: 489, Steps: 3, epsilon: 0.23, Reward: 1.0
# Episode: 490, Steps: 4, epsilon: 0.23, Reward: 1.0
# Episode: 491, Steps: 7, epsilon: 0.23, Reward: 1.0
# Episode: 492, Steps: 4, epsilon: 0.23, Reward: 1.0
# Episode: 493, Steps: 6, epsilon: 0.23, Reward: 1.0
# Episode: 494, Steps: 1, epsilon: 0.23, Reward: 0.0
# Episode: 495, Steps: 4, epsilon: 0.23, Reward: 1.0
# Episode: 496, Steps: 4, epsilon: 0.23, Reward: 1.0
# Episode: 497, Steps: 4, epsilon: 0.23, Reward: 1.0
# Episode: 498, Steps: 6, epsilon: 0.23, Reward: 1.0
# Episode: 499, Steps: 4, epsilon: 0.22, Reward: 1.0
# Episode: 500, Steps: 3, epsilon: 0.22, Reward: 1.0
# Average success rate of training episodes:  0.61

# %% [markdown]
# ### Plot cumulative average success rate over training episodes

# %%
# Plot cumulative average reward (or success rate) of the training phase.
# This shows how well the agent performs in the training phase.
df_reward_episodes = pd.DataFrame(reward_episodes)
cumulative_average_rewards = df_reward_episodes.expanding().mean()
plt.plot(cumulative_average_rewards)
plt.ylabel('Cumulative average reward')
plt.xlabel('Episodes')
plt.legend(['Training'], loc='upper left')
matplotlib.rcParams.update({'font.size': 10})
plt.show()

# %% [markdown]
# ### Plot cumulative average steps of over training episodes

# %%
# Plot cumulative average steps of the training phase.
# This shows how well the agent performs in the training phase.
df_step_episodes = pd.DataFrame(step_episodes)
cumulative_average_steps = df_step_episodes.expanding().mean()
plt.plot(cumulative_average_steps)
plt.ylabel('Cumulative average step')
plt.xlabel('Episodes')
plt.legend(['Training'], loc='upper left')
matplotlib.rcParams.update({'font.size': 10})
plt.show()

# %% [markdown]
# ### Plot epsilon values over training episodes

# %%
# Plot epsilon values over episodes
plt.plot(epsilon_episodes)
plt.ylabel('Epsilon value')
plt.xlabel('Episodes')
plt.legend(['Training'], loc='upper right')
matplotlib.rcParams.update({'font.size': 10})
plt.show()

# %% [markdown]
# ### Print optimal policy

# %%
# Print the optimal policy, i.e., at each state what is the best action to take.
for state_index in range(agent.state_size):
    state_arr=np.zeros(agent.state_size)    # Initialize state array, e.g., [[0. 0. 0. 0. 0. 0. 0. 0. 0.]]
    state_arr[state_index] = 1    # Set the agent position as if it is currently at each of the state
    state_arr= np.reshape(state_arr, [1, agent.state_size])    # Reshape state array
    q_values = agent.model.predict(state_arr, verbose=0)    # Get Q-values of all actions of the current state
    best_action = np.argmax(q_values)    # # Get max-Q-value action, i.e., best action to take
    print("State " + str(state_index) + ", Best action: " + str(best_action))
# Out:
# State 0, Best action: 1
# State 1, Best action: 2
# State 2, Best action: 1
# State 3, Best action: 1
# State 4, Best action: 1
# State 5, Best action: 1
# State 6, Best action: 2
# State 7, Best action: 2
# State 8, Best action: 1

# %% [markdown]
# ### Test the optimal policy

# %%
# Load the saved agent model.
# agent.load_model('model_500')    # Uncomment this line if you want to load a saved model from file

# Test an episode
state = env.reset()    # Reset environment, i.e., agent position is set to state 0
state_arr = np.zeros(agent.state_size)    # Initialze current state array, e.g., [0. 0. 0. 0. 0. 0. 0. 0. 0.]
state_arr[state[0]] = 1    # Set the agent position in the current state array, i.e., [1. 0. 0. 0. 0. 0. 0. 0. 0.]
state_arr = np.reshape(state_arr, [1, agent.state_size])    # Reshape array, e.g., [[1. 0. 0. 0. 0. 0. 0. 0. 0.]]
terminated = False    # Initialize terminated to False
img_lst = [env.render()]    # Initialize list to store visualization frames
for step in range(agent.max_steps):
    q_values = agent.model.predict(state_arr, verbose=0)    # Get Q-values of all actions of the current state
    best_action = np.argmax(q_values)    # Get max-Q-value action, i.e., best action to take
    new_state, reward, terminated, info, _ = env.step(best_action)    # Perform the best action, get return from environment
    new_state_arr = np.zeros(agent.state_size)    # Initialze new state array, e.g., [0. 0. 0. 0. 0. 0. 0. 0. 0.]
    new_state_arr[new_state] = 1    # Set the agent position in the new state array, after taking the action, e.g., [0. 1. 0. 0. 0. 0. 0. 0. 0.]
    new_state_arr = np.reshape(new_state_arr, [1, agent.state_size])    # Reshape array, e.g., [[0. 1. 0. 0. 0. 0. 0. 0. 0.]]
    print("Current state: " + str(np.argmax(state_arr)) + ", Action: " + str(best_action) + ", New state: " + str(np.argmax(new_state_arr)))
    state_arr = new_state_arr    # New state becomes state
    
    img = env.render()    # Render current environment image
    img_lst.append(img)    # Append environment images to make animation
    
    if terminated:    # If agent reaches Goal or Hole
        break    # End episode
        
print("Reward: " + str(reward))    # Print reward of the test episode
imageio.mimsave('test.gif', img_lst, format='GIF', duration=0.5)
# Out:
# Current state: 0, Action: 1, New state: 3
# Current state: 3, Action: 1, New state: 6
# Current state: 6, Action: 2, New state: 7
# Current state: 7, Action: 2, New state: 8
# Reward: 1.0

# %%
# Display test result animation
from IPython.display import Image
Image('test.gif')
