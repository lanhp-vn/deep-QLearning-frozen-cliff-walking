# %% [markdown]
# # Deep Q-Learning with Policy and Target network for Frozen-walk game
#
# This notebook aims at familiarizing you with training, validating and testing a reinforncement learning agent using Deep Q-Learning with Policy and Target network for Frozen-walk game.
#
# - Initiate a Frozen lake environment.
# - Initiate an agent.
# - Train the agent using <b>Deep Q-Learning with Policy and Target network</b>. You can base on the demo code to construct the target network as a copy of the policy network and periodically synchronized with the policy network.
# - Print out the optimal policy, i.e., what is the best action at a stage.
# - Compare and discuss the performance of the two approaches (1) one policy network and (2) one policy network and one target network, especially in regards of convergence stability.
#
# Frozen lake involves crossing a frozen lake from start to goal without falling into any holes by walking over the frozen lake. The player may not always move in the intended direction due to the slippery nature of the frozen lake.
#
# ![Frozen walk](https://gymnasium.farama.org/_images/frozen_lake.gif)
#
# More details can be found at https://gymnasium.farama.org/environments/toy_text/frozen_lake/.

# %% [markdown]
# ### Install libraries and initiate a frozen lake map

# %%
# Install gymnasium game environment
# !pip install gymnasium
# !pip install gymnasium[toy-text]
# Out:
# Requirement already satisfied: gymnasium in /usr/local/lib/python3.10/dist-packages (0.29.0)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (1.22.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (4.7.1)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (0.0.4)
# Requirement already satisfied: gymnasium[toy-text] in /usr/local/lib/python3.10/dist-packages (0.29.0)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[toy-text]) (1.22.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[toy-text]) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[toy-text]) (4.7.1)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium[toy-text]) (0.0.4)
# Requirement already satisfied: pygame>=2.1.3 in /usr/local/lib/python3.10/dist-packages (from gymnasium[toy-text]) (2.5.0)

# %%
### Please do not change this code

# Load libraries
import gymnasium as gym
import numpy as np
import random
import matplotlib.pyplot as plt
import matplotlib
from keras.optimizers import Adam
from keras.layers import Dense
from keras.models import Sequential
from collections import deque
import imageio
import pandas as pd
from IPython.display import Image

# %% [markdown]
# ## Hyperparameters

# %%
batch_size = 256
learning_rate = 0.001
epsilon_decay = 0.003
discount_factor = 0.9
train_episodes = 701

# %% [markdown]
# ## One Policy Network

# %%
np.random.seed(22)

# Define environment map
custom_map = [
    'SFF',
    'FHF',
    'FFG'
]

# Initialize the environment\
env = gym.make('FrozenLake-v1', desc=custom_map, is_slippery=False, render_mode='rgb_array')
state_size = env.observation_space.n    # Number of states
action_size = env.action_space.n    # Number of actions of this game: four, 0: left, 1:down, 2: right, 3: up.
env.reset()    # Reset environment, i.e., set agent position to state 0
plt.imshow(env.render())    # Visualize environment map

# %% [markdown]
# ### Define Agent

# %%
# Define agent attibutes and methods
class Agent:
    def __init__(self, state_size, action_size):
        self.memory = deque(maxlen=2048)   # Deque is quick for append and pop operations from both the ends of the container.
        self.batch_size = batch_size    # Batch size of data samples for training policy (and target) network. In this example, the two networks are identical.
        self.learning_rate = learning_rate    # Learning rate of
        self.epsilon = 1    # Start (max) value of epsilon
        self.min_eps = 0.01    # End (min) value of epsilon
        self.eps_decay = epsilon_decay     # Decay factor for decreasing epsilon over episodes
        self.gamma = discount_factor    # Discount factor
        self.state_size = state_size    # Number of states
        self.action_size =  action_size    # Number of possible actions the agent can take: four, 0: left, 1:down, 2: right, 3: up.
        self.episode = 0     # Agent current episode
        # self.epsilon_lst = []    # Track epsilon values over episodes
        self.max_steps = 50    # Maximum number of steps the agent can carry out in an episode
        self.train_episodes = train_episodes    # Number of training episodes
        self.model = self.build_model()    # Agent policy (and target model)

    # Build model architecture and compile it
    def build_model(self):
        model = Sequential()    # Initiate a simple sequential model
        model.add(Dense(10, input_dim=self.state_size, activation='relu'))    # Add a fully connected layer
        model.add(Dense(self.action_size, activation='linear'))    # Add a fully connected layer connecting to the network output
        model.compile(loss='mse', optimizer=Adam(learning_rate=self.learning_rate))    # Compile model with Mean Squared Error loss function
        return model

    # Add an eposide to agent's memory
    def add_memory(self, state, action, reward, new_state, terminated):
        self.memory.append((state, action, reward, new_state, terminated))    # Insert the value in its argument to the right end of the deque

    # Get action when agent is at a certain state
    def action(self, state):
        if np.random.rand() > self.epsilon:     # Epsilon starts at 1. rand > epsilon: exploit, rand <= epsilon: explore.
            return np.argmax(self.model.predict(state, verbose=0))     # Take greedy action. Verbose=0 mutes output prediction log.
        return env.action_space.sample()    # Take a random action in the action space

    # Train policy (and target) network. In this example, the two networks are identical.
    def replay(self):
        ### Process data batch
        minibatch = random.sample(self.memory, self.batch_size)    # Select a data batch for training
        minibatch_state = np.concatenate(np.array(minibatch, dtype=object)[:, 0], axis=0)    # Extract 'state' batch from the data batch
        minibatch_action = np.array(minibatch, dtype=object)[:, 1]    # Extract 'action' batch from the data batch
        minibatch_reward = np.array(minibatch, dtype=object)[:, 2]    # Extract 'reward' batch from the data batch
        minibatch_new_state = np.concatenate(np.array(minibatch, dtype=object)[:, 3], axis=0)    # Extract 'new_state' batch from the data batch
        minibatch_terminated = np.array(minibatch, dtype=object)[:, 4]    # Extract 'terminated' batch from the data batch

        ### Feed state to the network for training
        q_state = self.model.predict(minibatch_state, verbose=0)    # First pass: feed current state to the network to get current Q-values
        q_new_state = self.model.predict(minibatch_new_state, verbose=0)    # Second pass: feed new state to the network to get next Q-values

        q_action_optimal = np.add(minibatch_reward, self.gamma * np.amax(q_new_state, axis=1))    # Calculate the optimal Q-values of actions from the current state
        for i in range(0, self.batch_size):
            q_state[i][minibatch_action[i]] = q_action_optimal[i]    # Update optimal Q-values back to 'q_state' variable

        self.model.fit(minibatch_state, q_state, epochs=1, verbose=0)    # Train the network with the optimal Q-values, i.e., now in 'q_state' variable. x is minibatch_state and y is q_state. Loss is MSE.

    # Save model
    def save_model(self, name):
        self.model.save_weights(name)

    # Load model
    def load_model(self, name):
        self.model.load_weights(name)

# Initialize a reinforcement learning agent
agent = Agent(state_size, action_size)

# %% [markdown]
# ### Train the Agent

# %%
reward_episodes = []    # Track rewards over episodes
step_episodes = []    # Track number of steps (in each episode until termination) over episodes
epsilon_episodes = []    # Track epsilon values over episodes
outcomes = []    # List to store the outcomes of each episode for plotting

for episode in range(agent.train_episodes):
    agent.episode = episode    # Set agent's current episode
    state = env.reset()    # Reset environment, i.e., agent position is set to state 0
    state_arr = np.zeros(agent.state_size)    # Initialze current state array, e.g., [0. 0. 0. 0. 0. 0. 0. 0. 0.]
    state_arr[state[0]] = 1    # Set the agent position in the current state array, i.e., [[1. 0. 0. 0. 0. 0. 0. 0. 0.]]
    state_arr = np.reshape(state_arr, [1, agent.state_size])    # Reshape array
    reward = 0    # Initialize reward to zero
    terminated = False    # Initialize terminated to False
    # By default, we consider our outcome to be a failure for this episode
    outcomes.append("Failure")

    img_lst = [env.render()]    # Initialize list to store visualization frames
    for step in range(agent.max_steps):
        action = agent.action(state_arr)    # Take action at the current state. This ccan be exploitation or exploration, depending on agent.epsilon
        new_state, reward, terminated, info, _ = env.step(action)     # Terminated: whether a terminal state is reached after taking the action. Ref: https://www.gymlibrary.dev/api/core/#gym.Env.step
        new_state_arr = np.zeros(agent.state_size)    # Initialze new state array, e.g., [[0. 0. 0. 0. 0. 0. 0. 0. 0.]]
        new_state_arr[new_state] = 1    # Set the agent position in the new state array, after taking the action, e.g., [[0. 1. 0. 0. 0. 0. 0. 0. 0.]]
        new_state_arr = np.reshape(new_state_arr, [1, agent.state_size])    # Reshape array
        agent.add_memory(state_arr, action, reward, new_state_arr, terminated)    # Add current step to agent's memory
        state_arr = new_state_arr    # New state becomes state

        # If the agent receives a reward, it means that the outcome for this episode is a success
        if reward:
            outcomes[-1] = "Success"

        # Render map imgage for visualization every K episodes
        if agent.episode % 50 == 0:
            animation_file = "one_training_episode_" + str(agent.episode) + "_steps_" + str(step) + ".gif"
            img = env.render()    # Render current environment image
            img_lst.append(img)    # Append environment images to make animation

        if terminated:    # if agent reaches Goal
            break    # End episode

    print("Episode: " + str(agent.episode) + ", Steps: " + str(step) + ", epsilon: " + str(round(agent.epsilon,2)) + ", Reward: " + str(reward))
    reward_episodes.append(reward)    # Add reward to list for tracking purpose
    step_episodes.append(step)    # Add step to list for tracking purpose
    epsilon_episodes.append(agent.epsilon)    # Add epsilon to list for tracking purpose

    ### Update epsilon value which is the ratio of exploitation and exploration
    if agent.epsilon < agent.min_eps:
        agent.epsilon = agent.min_eps    # Set the minimum value of epsilon so that there is always a chance for exploration.
    else:
        agent.epsilon = np.exp(-agent.eps_decay*agent.episode)    # Decrease exploration / Increase exploitation overtime as the agent knows more about the environment

    ### If enough experiences collected in the memory, use them for training
    if len(agent.memory) > agent.batch_size:
        agent.replay()

    ### Write animation of the training episode (n*K)th
    if len(img_lst)>1:
        imageio.mimsave(animation_file, img_lst, format='GIF', duration=0.5)

print('Average success rate of training episodes: ', round(np.mean(reward_episodes),2))
agent.save_model('model_' + str(agent.episode))    # Save model
# Out:
# Episode: 0, Steps: 22, epsilon: 1, Reward: 0.0
# Episode: 1, Steps: 3, epsilon: 1.0, Reward: 0.0
# Episode: 2, Steps: 5, epsilon: 1.0, Reward: 0.0
# Episode: 3, Steps: 11, epsilon: 0.99, Reward: 1.0
# Episode: 4, Steps: 23, epsilon: 0.99, Reward: 1.0
# Episode: 5, Steps: 2, epsilon: 0.99, Reward: 0.0
# Episode: 6, Steps: 6, epsilon: 0.99, Reward: 0.0
# Episode: 7, Steps: 9, epsilon: 0.98, Reward: 0.0
# Episode: 8, Steps: 6, epsilon: 0.98, Reward: 0.0
# Episode: 9, Steps: 13, epsilon: 0.98, Reward: 0.0
# Episode: 10, Steps: 14, epsilon: 0.97, Reward: 0.0
# Episode: 11, Steps: 12, epsilon: 0.97, Reward: 1.0
# Episode: 12, Steps: 7, epsilon: 0.97, Reward: 1.0
# Episode: 13, Steps: 5, epsilon: 0.96, Reward: 0.0
# Episode: 14, Steps: 1, epsilon: 0.96, Reward: 0.0
# Episode: 15, Steps: 1, epsilon: 0.96, Reward: 0.0
# Episode: 16, Steps: 3, epsilon: 0.96, Reward: 0.0
# Episode: 17, Steps: 17, epsilon: 0.95, Reward: 0.0
Steps: 3, epsilon: 0.13, Reward: 1.0
# Episode: 687, Steps: 3, epsilon: 0.13, Reward: 1.0
# Episode: 688, Steps: 3, epsilon: 0.13, Reward: 1.0
# Episode: 689, Steps: 3, epsilon: 0.13, Reward: 1.0
# Episode: 690, Steps: 3, epsilon: 0.13, Reward: 1.0
# Episode: 691, Steps: 4, epsilon: 0.13, Reward: 1.0
# Episode: 692, Steps: 3, epsilon: 0.13, Reward: 1.0
# Episode: 693, Steps: 3, epsilon: 0.13, Reward: 1.0
# Episode: 694, Steps: 4, epsilon: 0.13, Reward: 1.0
# Episode: 695, Steps: 4, epsilon: 0.12, Reward: 1.0
# Episode: 696, Steps: 5, epsilon: 0.12, Reward: 1.0
# Episode: 697, Steps: 4, epsilon: 0.12, Reward: 1.0
# Episode: 698, Steps: 3, epsilon: 0.12, Reward: 1.0
# Episode: 699, Steps: 4, epsilon: 0.12, Reward: 1.0
# Episode: 700, Steps: 5, epsilon: 0.12, Reward: 1.0
# Average success rate of training episodes:  0.67

# %% [markdown]
# ### Performance Review

# %%
print('Average success rate of training episodes: ', round(np.mean(reward_episodes),2))
# Out:
# Average success rate of training episodes:  0.67

# %%
# Plotting the outcomes of each episode
plt.figure(figsize=(12, 5))
plt.xlabel("Episode number")
plt.ylabel("Outcome")
ax = plt.gca()
ax.set_facecolor('#efeeea')
plt.bar(range(len(outcomes)), outcomes, color="#0A047A", width=1.0)
plt.show()

# %%
# Plot cumulative average reward (or success rate) of the training phase.
# This shows how well the agent performs in the training phase.
df_reward_episodes = pd.DataFrame(reward_episodes)
cumulative_average_rewards = df_reward_episodes.expanding().mean()
plt.plot(cumulative_average_rewards)
plt.ylabel('Cumulative average reward')
plt.xlabel('Episodes')
plt.legend(['Training'], loc='upper left')
matplotlib.rcParams.update({'font.size': 10})
plt.show()

# %%
# Plot cumulative average steps of the training phase.
# This shows how well the agent performs in the training phase.
df_step_episodes = pd.DataFrame(step_episodes)
cumulative_average_steps = df_step_episodes.expanding().mean()
plt.plot(cumulative_average_steps)
plt.ylabel('Cumulative average step')
plt.xlabel('Episodes')
plt.legend(['Training'], loc='upper left')
matplotlib.rcParams.update({'font.size': 10})
plt.show()

# %%
# Plot epsilon values over episodes
plt.plot(epsilon_episodes)
plt.ylabel('Epsilon value')
plt.xlabel('Episodes')
plt.legend(['Training'], loc='upper right')
matplotlib.rcParams.update({'font.size': 10})
plt.show()

# %% [markdown]
# ### Print and test optimial policy

# %%
# Print the optimal policy, i.e., at each state what is the best action to take.
for state_index in range(agent.state_size):
    state_arr=np.zeros(agent.state_size)    # Initialize state array, e.g., [[0. 0. 0. 0. 0. 0. 0. 0. 0.]]
    state_arr[state_index] = 1    # Set the agent position as if it is currently at each of the state
    state_arr= np.reshape(state_arr, [1, agent.state_size])    # Reshape state array
    q_values = agent.model.predict(state_arr, verbose=0)    # Get Q-values of all actions of the current state
    best_action = np.argmax(q_values)    # # Get max-Q-value action, i.e., best action to take
    print("State " + str(state_index) + ", Best action: " + str(best_action))
# Out:
# State 0, Best action: 1
# State 1, Best action: 2
# State 2, Best action: 1
# State 3, Best action: 1
# State 4, Best action: 2
# State 5, Best action: 1
# State 6, Best action: 2
# State 7, Best action: 2
# State 8, Best action: 2

# %%
# Load the saved agent model.
# agent.load_model('model_500')    # Uncomment this line if you want to load a saved model from file

# Test an episode
state = env.reset()    # Reset environment, i.e., agent position is set to state 0
state_arr = np.zeros(agent.state_size)    # Initialze current state array, e.g., [0. 0. 0. 0. 0. 0. 0. 0. 0.]
state_arr[state[0]] = 1    # Set the agent position in the current state array, i.e., [1. 0. 0. 0. 0. 0. 0. 0. 0.]
state_arr = np.reshape(state_arr, [1, agent.state_size])    # Reshape array, e.g., [[1. 0. 0. 0. 0. 0. 0. 0. 0.]]
terminated = False    # Initialize terminated to False
img_lst = [env.render()]    # Initialize list to store visualization frames

for step in range(agent.max_steps):
    q_values = agent.model.predict(state_arr, verbose=0)    # Get Q-values of all actions of the current state
    best_action = np.argmax(q_values)    # Get max-Q-value action, i.e., best action to take
    new_state, reward, terminated, info, _ = env.step(best_action)    # Perform the best action, get return from environment
    new_state_arr = np.zeros(agent.state_size)    # Initialze new state array, e.g., [0. 0. 0. 0. 0. 0. 0. 0. 0.]
    new_state_arr[new_state] = 1    # Set the agent position in the new state array, after taking the action, e.g., [0. 1. 0. 0. 0. 0. 0. 0. 0.]
    new_state_arr = np.reshape(new_state_arr, [1, agent.state_size])    # Reshape array, e.g., [[0. 1. 0. 0. 0. 0. 0. 0. 0.]]
    print("Current state: " + str(np.argmax(state_arr)) + ", Action: " + str(best_action) + ", New state: " + str(np.argmax(new_state_arr)))
    state_arr = new_state_arr    # New state becomes state

    img = env.render()    # Render current environment image
    img_lst.append(img)    # Append environment images to make animation

    if terminated:    # If agent reaches Goal or Hole
        break    # End episode

print("Reward: " + str(reward))    # Print reward of the test episode
imageio.mimsave('one_test.gif', img_lst, format='GIF', duration=0.5)
# Out:
# Current state: 0, Action: 1, New state: 3
# Current state: 3, Action: 1, New state: 6
# Current state: 6, Action: 2, New state: 7
# Current state: 7, Action: 2, New state: 8
# Reward: 1.0

# %%
# Display test result animation
from IPython.display import Image
Image('one_test.gif')

# %% [markdown]
# ## One Policy Network and One Target Network

# %%
np.random.seed(22)

# Define environment map
custom_map = [
    'SFF',
    'FHF',
    'FFG'
]

# Initialize the environment\
env = gym.make('FrozenLake-v1', desc=custom_map, is_slippery=False, render_mode='rgb_array')
state_size = env.observation_space.n    # Number of states
action_size = env.action_space.n    # Number of actions of this game: four, 0: left, 1:down, 2: right, 3: up.
env.reset()    # Reset environment, i.e., set agent position to state 0
plt.imshow(env.render())    # Visualize environment map

# %% [markdown]
# ### Define Agent

# %%
# Define agent attibutes and methods
class Agent:
    def __init__(self, state_size, action_size):
        self.memory = deque(maxlen=2048)   # Deque is quick for append and pop operations from both the ends of the container.
        self.batch_size = batch_size    # Batch size of data samples for training policy (and target) network
        self.learning_rate = learning_rate    # Learning rate of
        self.epsilon = 1    # Start (max) value of epsilon
        self.min_eps = 0.01    # End (min) value of epsilon
        self.eps_decay = epsilon_decay     # Decay factor for decreasing epsilon over episodes
        self.gamma = discount_factor    # Discount factor
        self.state_size = state_size    # Number of states
        self.action_size =  action_size    # Number of possible actions the agent can take: four, 0: left, 1:down, 2: right, 3: up.
        self.episode = 0     # Agent current episode
        # self.epsilon_lst = []    # Track epsilon values over episodes
        self.max_steps = 50    # Maximum number of steps the agent can carry out in an episode
        self.train_episodes = train_episodes    # Number of training episodes
        self.model = self.build_model()    # Agent policy (and target model)
        self.target_model = self.build_target_model()    # Create the target model
        self.update_target_model()    # Initialize the target model with the initial weights of the policy network


    # Build model architecture and compile it
    def build_model(self):
        model = Sequential()    # Initiate a simple sequential model
        model.add(Dense(10, input_dim=self.state_size, activation='relu'))    # Add a fully connected layer
        model.add(Dense(self.action_size, activation='linear'))    # Add a fully connected layer connecting to the network output
        model.compile(loss='mse', optimizer=Adam(learning_rate=self.learning_rate))    # Compile model with Mean Squared Error loss function
        return model

    def build_target_model(self):
        target_model = Sequential()    # Initiate a simple sequential model
        target_model.add(Dense(10, input_dim=self.state_size, activation='relu'))    # Add a fully connected layer
        target_model.add(Dense(self.action_size, activation='linear'))    # Add a fully connected layer connecting to the network output
        target_model.compile(loss='mse', optimizer=Adam(learning_rate=self.learning_rate))    # Compile model with Mean Squared Error loss function
        return target_model

    def update_target_model(self):
        self.target_model.set_weights(self.model.get_weights())

    # Add an eposide to agent's memory
    def add_memory(self, state, action, reward, new_state, terminated):
        self.memory.append((state, action, reward, new_state, terminated))    # Insert the value in its argument to the right end of the deque

    # Get action when agent is at a certain state
    def action(self, state):
        if np.random.rand() > self.epsilon:     # Epsilon starts at 1. rand > epsilon: exploit, rand <= epsilon: explore.
            return np.argmax(self.model.predict(state, verbose=0))     # Take greedy action. Verbose=0 mutes output prediction log.
        return env.action_space.sample()    # Take a random action in the action space

    # Train policy (and target) network.
    def replay(self):
        minibatch = random.sample(self.memory, self.batch_size)
        minibatch_state = np.concatenate(np.array(minibatch, dtype=object)[:, 0], axis=0)
        minibatch_action = np.array(minibatch, dtype=object)[:, 1]
        minibatch_reward = np.array(minibatch, dtype=object)[:, 2]
        minibatch_new_state = np.concatenate(np.array(minibatch, dtype=object)[:, 3], axis=0)
        minibatch_terminated = np.array(minibatch, dtype=object)[:, 4]

        q_state = self.model.predict(minibatch_state, verbose=0)
        q_new_state_target = self.target_model.predict(minibatch_new_state, verbose=0)
        q_action_optimal = np.add(minibatch_reward, self.gamma * np.amax(q_new_state_target, axis=1))

        for i in range(0, self.batch_size):
            q_state[i][minibatch_action[i]] = q_action_optimal[i]

        self.model.fit(minibatch_state, q_state, epochs=1, verbose=0)
        self.update_target_model()

    # Save model
    def save_model(self, name):
        self.model.save_weights(name)

    # Load model
    def load_model(self, name):
        self.model.load_weights(name)

# Initialize a reinforcement learning agent
agent = Agent(state_size, action_size)

# %% [markdown]
# ### Train the agent

# %%
reward_episodes = []    # Track rewards over episodes
step_episodes = []    # Track number of steps (in each episode until termination) over episodes
epsilon_episodes = []    # Track epsilon values over episodes
outcomes = []    # List to store the outcomes of each episode for plotting

for episode in range(agent.train_episodes):
    agent.episode = episode    # Set agent's current episode
    state = env.reset()    # Reset environment, i.e., agent position is set to state 0
    state_arr = np.zeros(agent.state_size)    # Initialze current state array, e.g., [0. 0. 0. 0. 0. 0. 0. 0. 0.]
    state_arr[state[0]] = 1    # Set the agent position in the current state array, i.e., [[1. 0. 0. 0. 0. 0. 0. 0. 0.]]
    state_arr = np.reshape(state_arr, [1, agent.state_size])    # Reshape array
    reward = 0    # Initialize reward to zero
    terminated = False    # Initialize terminated to False
    # By default, we consider our outcome to be a failure for this episode
    outcomes.append("Failure")

    img_lst = [env.render()]    # Initialize list to store visualization frames
    for step in range(agent.max_steps):
        action = agent.action(state_arr)    # Take action at the current state. This ccan be exploitation or exploration, depending on agent.epsilon
        new_state, reward, terminated, info, _ = env.step(action)     # Terminated: whether a terminal state is reached after taking the action. Ref: https://www.gymlibrary.dev/api/core/#gym.Env.step
        new_state_arr = np.zeros(agent.state_size)    # Initialze new state array, e.g., [[0. 0. 0. 0. 0. 0. 0. 0. 0.]]
        new_state_arr[new_state] = 1    # Set the agent position in the new state array, after taking the action, e.g., [[0. 1. 0. 0. 0. 0. 0. 0. 0.]]
        new_state_arr = np.reshape(new_state_arr, [1, agent.state_size])    # Reshape array
        agent.add_memory(state_arr, action, reward, new_state_arr, terminated)    # Add current step to agent's memory
        state_arr = new_state_arr    # New state becomes state

        # If the agent receives a reward, it means that the outcome for this episode is a success
        if reward:
            outcomes[-1] = "Success"

        # Render map imgage for visualization every K episodes
        if agent.episode % 50 == 0:
            animation_file = "two_training_episode_" + str(agent.episode) + "_steps_" + str(step) + ".gif"
            img = env.render()    # Render current environment image
            img_lst.append(img)    # Append environment images to make animation

        if terminated:    # if agent reaches Goal
            break    # End episode

    print("Episode: " + str(agent.episode) + ", Steps: " + str(step) + ", epsilon: " + str(round(agent.epsilon,2)) + ", Reward: " + str(reward))
    reward_episodes.append(reward)    # Add reward to list for tracking purpose
    step_episodes.append(step)    # Add step to list for tracking purpose
    epsilon_episodes.append(agent.epsilon)    # Add epsilon to list for tracking purpose

    ### Update epsilon value which is the ratio of exploitation and exploration
    if agent.epsilon < agent.min_eps:
        agent.epsilon = agent.min_eps    # Set the minimum value of epsilon so that there is always a chance for exploration.
    else:
        agent.epsilon = np.exp(-agent.eps_decay*agent.episode)    # Decrease exploration / Increase exploitation overtime as the agent knows more about the environment

    ### If enough experiences collected in the memory, use them for training
    if len(agent.memory) > agent.batch_size:
        agent.replay()

    ### Write animation of the training episode (n*K)th
    if len(img_lst)>1:
        imageio.mimsave(animation_file, img_lst, format='GIF', duration=0.5)

print('Average success rate of training episodes: ', round(np.mean(reward_episodes),2))
agent.save_model('model_' + str(agent.episode))    # Save model
# Out:
# Episode: 0, Steps: 1, epsilon: 1, Reward: 0.0
# Episode: 1, Steps: 8, epsilon: 1.0, Reward: 1.0
# Episode: 2, Steps: 10, epsilon: 1.0, Reward: 1.0
# Episode: 3, Steps: 16, epsilon: 0.99, Reward: 1.0
# Episode: 4, Steps: 9, epsilon: 0.99, Reward: 0.0
# Episode: 5, Steps: 29, epsilon: 0.99, Reward: 1.0
# Episode: 6, Steps: 12, epsilon: 0.99, Reward: 0.0
# Episode: 7, Steps: 8, epsilon: 0.98, Reward: 0.0
# Episode: 8, Steps: 1, epsilon: 0.98, Reward: 0.0
# Episode: 9, Steps: 3, epsilon: 0.98, Reward: 0.0
# Episode: 10, Steps: 1, epsilon: 0.97, Reward: 0.0
# Episode: 11, Steps: 27, epsilon: 0.97, Reward: 0.0
# Episode: 12, Steps: 3, epsilon: 0.97, Reward: 0.0
# Episode: 13, Steps: 7, epsilon: 0.96, Reward: 1.0
# Episode: 14, Steps: 1, epsilon: 0.96, Reward: 0.0
# Episode: 15, Steps: 4, epsilon: 0.96, Reward: 0.0
# Episode: 16, Steps: 3, epsilon: 0.96, Reward: 0.0
# Episode: 17, Steps: 16, epsilon: 0.95, Reward: 1.0
# Episode: 18, Steps: 14, epsilon: 0.95, Reward: 0.0
Steps: 3, epsilon: 0.15, Reward: 1.0
# Episode: 641, Steps: 5, epsilon: 0.15, Reward: 1.0
# Episode: 642, Steps: 3, epsilon: 0.15, Reward: 1.0
# Episode: 643, Steps: 3, epsilon: 0.15, Reward: 1.0
# Episode: 644, Steps: 3, epsilon: 0.15, Reward: 1.0
# Episode: 645, Steps: 5, epsilon: 0.14, Reward: 1.0
# Episode: 646, Steps: 3, epsilon: 0.14, Reward: 1.0
# Episode: 647, Steps: 3, epsilon: 0.14, Reward: 1.0
# Episode: 648, Steps: 5, epsilon: 0.14, Reward: 1.0
# Episode: 649, Steps: 3, epsilon: 0.14, Reward: 1.0
# Episode: 650, Steps: 3, epsilon: 0.14, Reward: 1.0
# Episode: 651, Steps: 4, epsilon: 0.14, Reward: 1.0
# Episode: 652, Steps: 3, epsilon: 0.14, Reward: 1.0
# Episode: 653, Steps: 2, epsilon: 0.14, Reward: 0.0
# Episode: 654, Steps: 3, epsilon: 0.14, Reward: 1.0
# Episode: 655, Steps: 3, epsilon: 0.14, Reward: 1.0
# Episode: 656, Steps: 4, epsilon: 0.14, Reward: 1.0
# Episode: 657, Steps: 3, epsilon: 0.14, Reward: 1.0
# Episode: 658, Steps: 4, epsilon: 0.14, Reward: 1.0
# Episode: 659, Steps: 3, epsilon: 0.14, Reward: 1.0
# Episode: 660, Steps: 4, epsilon: 0.14, Reward: 1.0
# Episode: 661, Steps: 3, epsilon: 0.14, Reward: 1.0
# Episode: 662, Steps: 3, epsilon: 0.14, Reward: 1.0
# Episode: 663, Steps: 3, epsilon: 0.14, Reward: 1.0
# Episode: 664, Steps: 3, epsilon: 0.14, Reward: 1.0
# Episode: 665, Steps: 6, epsilon: 0.14, Reward: 1.0
# Episode: 666, Steps: 4, epsilon: 0.14, Reward: 1.0
# Episode: 667, Steps: 3, epsilon: 0.14, Reward: 1.0
# Episode: 668, Steps: 4, epsilon: 0.14, Reward: 1.0
# Episode: 669, Steps: 3, epsilon: 0.13, Reward: 1.0
# Episode: 670, Steps: 3, epsilon: 0.13, Reward: 1.0
# Episode: 671, Steps: 3, epsilon: 0.13, Reward: 1.0
# Episode: 672, Steps: 3, epsilon: 0.13, Reward: 1.0
# Episode: 673, Steps: 3, epsilon: 0.13, Reward: 1.0
# Episode: 674, Steps: 4, epsilon: 0.13, Reward: 1.0
# Episode: 675, Steps: 3, epsilon: 0.13, Reward: 1.0
# Episode: 676, Steps: 3, epsilon: 0.13, Reward: 1.0
# Episode: 677, Steps: 3, epsilon: 0.13, Reward: 1.0
# Episode: 678, Steps: 3, epsilon: 0.13, Reward: 1.0
# Episode: 679, Steps: 3, epsilon: 0.13, Reward: 1.0
# Episode: 680, Steps: 7, epsilon: 0.13, Reward: 1.0
# Episode: 681, Steps: 4, epsilon: 0.13, Reward: 1.0
# Episode: 682, Steps: 3, epsilon: 0.13, Reward: 1.0
# Episode: 683, Steps: 3, epsilon: 0.13, Reward: 1.0
# Episode: 684, Steps: 3, epsilon: 0.13, Reward: 1.0
# Episode: 685, Steps: 3, epsilon: 0.13, Reward: 1.0
# Episode: 686, Steps: 3, epsilon: 0.13, Reward: 1.0
# Episode: 687, Steps: 3, epsilon: 0.13, Reward: 1.0
# Episode: 688, Steps: 3, epsilon: 0.13, Reward: 1.0
# Episode: 689, Steps: 3, epsilon: 0.13, Reward: 1.0
# Episode: 690, Steps: 5, epsilon: 0.13, Reward: 1.0
# Episode: 691, Steps: 2, epsilon: 0.13, Reward: 0.0
# Episode: 692, Steps: 3, epsilon: 0.13, Reward: 1.0
# Episode: 693, Steps: 3, epsilon: 0.13, Reward: 1.0
# Episode: 694, Steps: 3, epsilon: 0.13, Reward: 1.0
# Episode: 695, Steps: 3, epsilon: 0.12, Reward: 1.0
# Episode: 696, Steps: 3, epsilon: 0.12, Reward: 1.0
# Episode: 697, Steps: 3, epsilon: 0.12, Reward: 1.0
# Episode: 698, Steps: 3, epsilon: 0.12, Reward: 1.0
# Episode: 699, Steps: 4, epsilon: 0.12, Reward: 1.0
# Episode: 700, Steps: 3, epsilon: 0.12, Reward: 1.0
# Average success rate of training episodes:  0.71

# %% [markdown]
# ### Performance Review

# %%
print('Average success rate of training episodes: ', round(np.mean(reward_episodes),2))
# Out:
# Average success rate of training episodes:  0.71

# %%
# Plotting the outcomes of each episode
plt.figure(figsize=(12, 5))
plt.xlabel("Episode number")
plt.ylabel("Outcome")
ax = plt.gca()
ax.set_facecolor('#efeeea')
plt.bar(range(len(outcomes)), outcomes, color="#0A047A", width=1.0)
plt.show()

# %%
# Plot cumulative average reward (or success rate) of the training phase.
# This shows how well the agent performs in the training phase.
df_reward_episodes = pd.DataFrame(reward_episodes)
cumulative_average_rewards = df_reward_episodes.expanding().mean()
plt.plot(cumulative_average_rewards)
plt.ylabel('Cumulative average reward')
plt.xlabel('Episodes')
plt.legend(['Training'], loc='upper left')
matplotlib.rcParams.update({'font.size': 10})
plt.show()

# %%
# Plot cumulative average steps of the training phase.
# This shows how well the agent performs in the training phase.
df_step_episodes = pd.DataFrame(step_episodes)
cumulative_average_steps = df_step_episodes.expanding().mean()
plt.plot(cumulative_average_steps)
plt.ylabel('Cumulative average step')
plt.xlabel('Episodes')
plt.legend(['Training'], loc='upper left')
matplotlib.rcParams.update({'font.size': 10})
plt.show()

# %%
# Plot epsilon values over episodes
plt.plot(epsilon_episodes)
plt.ylabel('Epsilon value')
plt.xlabel('Episodes')
plt.legend(['Training'], loc='upper right')
matplotlib.rcParams.update({'font.size': 10})
plt.show()

# %% [markdown]
# ### Print and test optimal policy

# %%
# Print the optimal policy, i.e., at each state what is the best action to take.
for state_index in range(agent.state_size):
    state_arr=np.zeros(agent.state_size)    # Initialize state array, e.g., [[0. 0. 0. 0. 0. 0. 0. 0. 0.]]
    state_arr[state_index] = 1    # Set the agent position as if it is currently at each of the state
    state_arr= np.reshape(state_arr, [1, agent.state_size])    # Reshape state array
    q_values = agent.model.predict(state_arr, verbose=0)    # Get Q-values of all actions of the current state
    best_action = np.argmax(q_values)    # # Get max-Q-value action, i.e., best action to take
    print("State " + str(state_index) + ", Best action: " + str(best_action))
# Out:
# State 0, Best action: 2
# State 1, Best action: 2
# State 2, Best action: 1
# State 3, Best action: 1
# State 4, Best action: 2
# State 5, Best action: 1
# State 6, Best action: 2
# State 7, Best action: 2
# State 8, Best action: 2

# %%
# Load the saved agent model.
# agent.load_model('model_500')    # Uncomment this line if you want to load a saved model from file

# Test an episode
state = env.reset()    # Reset environment, i.e., agent position is set to state 0
state_arr = np.zeros(agent.state_size)    # Initialze current state array, e.g., [0. 0. 0. 0. 0. 0. 0. 0. 0.]
state_arr[state[0]] = 1    # Set the agent position in the current state array, i.e., [1. 0. 0. 0. 0. 0. 0. 0. 0.]
state_arr = np.reshape(state_arr, [1, agent.state_size])    # Reshape array, e.g., [[1. 0. 0. 0. 0. 0. 0. 0. 0.]]
terminated = False    # Initialize terminated to False
img_lst = [env.render()]    # Initialize list to store visualization frames
for step in range(agent.max_steps):
    q_values = agent.model.predict(state_arr, verbose=0)    # Get Q-values of all actions of the current state
    best_action = np.argmax(q_values)    # Get max-Q-value action, i.e., best action to take
    new_state, reward, terminated, info, _ = env.step(best_action)    # Perform the best action, get return from environment
    new_state_arr = np.zeros(agent.state_size)    # Initialze new state array, e.g., [0. 0. 0. 0. 0. 0. 0. 0. 0.]
    new_state_arr[new_state] = 1    # Set the agent position in the new state array, after taking the action, e.g., [0. 1. 0. 0. 0. 0. 0. 0. 0.]
    new_state_arr = np.reshape(new_state_arr, [1, agent.state_size])    # Reshape array, e.g., [[0. 1. 0. 0. 0. 0. 0. 0. 0.]]
    print("Current state: " + str(np.argmax(state_arr)) + ", Action: " + str(best_action) + ", New state: " + str(np.argmax(new_state_arr)))
    state_arr = new_state_arr    # New state becomes state

    img = env.render()    # Render current environment image
    img_lst.append(img)    # Append environment images to make animation

    if terminated:    # If agent reaches Goal or Hole
        break    # End episode

print("Reward: " + str(reward))    # Print reward of the test episode
imageio.mimsave('two_test.gif', img_lst, format='GIF', duration=0.5)
# Out:
# Current state: 0, Action: 2, New state: 1
# Current state: 1, Action: 2, New state: 2
# Current state: 2, Action: 1, New state: 5
# Current state: 5, Action: 1, New state: 8
# Reward: 1.0

# %%
# Display test result animation
Image('two_test.gif')

# %% [markdown]
# ## Comparison

# %% [markdown]
# Since the presented 3x3 FrozenLake is not sufficiently noisy and complex to challenge the limitations of the one policy network (i.e., overestimation bias), the difference in the performance between the one policy network and the policy + target network is not significant.
#
# Regarding the convergence stability, it can be observed in the two plots of cumulative average reward (or success rate) of the training phase that there is delayed learning occurred in the policy + target network due to the periodic update of the target network. Although learning can be slower compared to using a single policy network alone, this delay is potentially often outweighed by the stability and performance improvements achieved in a noisy and complex environment.
